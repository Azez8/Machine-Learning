# %% [markdown]
# ARTI308 - Machine Learning
# # Seaborn Overview
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
#
#
#
# ## Distribution Plots
#
# Let's discuss some plots that allow us to visualize the distribution of a data set. These plots are:
#
# * distplot
# * jointplot
# * pairplot
# * rugplot
# * kdeplot

# %% [markdown]
# ## Imports

# %%
# Import seaborn library for advanced statistical data visualization
import seaborn as sns

# Display plots inline inside Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Data
# Seaborn comes with built-in data sets!

# %%
# Load built-in 'tips' dataset from seaborn
tips = sns.load_dataset('tips')

# %%
# Display first 5 rows of the dataset
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## distplot
#
# The distplot shows the distribution of a univariate set of observations.

# %%
sns.distplot(tips['total_bill'])
# Safe to ignore warnings

# %% [markdown]
# To remove the kde layer and just have the histogram use:

# %%
# Create a histogram of total_bill
# kde=False → disable density curve
# bins=30 → divide data into 30 intervals
sns.distplot(tips['total_bill'], kde=False, bins=30)

# %% [markdown]
# ## jointplot
#
# jointplot() allows you to basically match up two distplots for bivariate data. With your choice of what **kind** parameter to compare with:
# * “scatter”
# * “reg”
# * “resid”
# * “kde”
# * “hex”

# %%
# Create scatter joint plot showing relationship between total_bill and tip
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter')

# %%
# Create hexbin joint plot to show density of points
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
# Create regression joint plot (adds regression line)
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %% [markdown]
# ## pairplot
#
# pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns) and supports a color hue argument (for categorical columns).

# %%
# Create pairplot to show relationships between all numerical columns
sns.pairplot(tips)

# %%
# Create pairplot and color points by 'sex' column
# palette='coolwarm' → color theme
sns.pairplot(tips, hue='sex', palette='coolwarm')

# %% [markdown]
# ## rugplot
#
# rugplots are actually a very simple concept, they just draw a dash mark for every point on a univariate distribution. They are the building block of a KDE plot:

# %%
# Add rug plot to show individual data points on total_bill axis
sns.rugplot(tips['total_bill'])

# %% [markdown]
# ## kdeplot
#
# kdeplots are [Kernel Density Estimation plots](http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth). These KDE plots replace every single observation with a Gaussian (Normal) distribution centered around that value. For example:

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")

# %% [markdown]
# So with our tips dataset:

# %%
# Plot KDE (density curve) for total_bill
sns.kdeplot(tips['total_bill'])

# Overlay rug plot for better visualization of data distribution
sns.rugplot(tips['total_bill'])

# %%
# Plot KDE for tip amounts
sns.kdeplot(tips['tip'])

# Add rug plot to show individual tip values
sns.rugplot(tips['tip'])

# %% [markdown]
# # Categorical Data Plots
#
# Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:
#
# * factorplot
# * boxplot
# * violinplot
# * stripplot
# * swarmplot
# * barplot
# * countplot
#
# Let's go through examples of each!

# %%
# Import seaborn for statistical visualization
import seaborn as sns

# Display plots directly inside Jupyter Notebook
# %matplotlib inline

# %%
# Load built-in dataset called "tips"
tips = sns.load_dataset('tips')

# Show first 5 rows of the dataset
tips.head()

# %% [markdown]
# ## barplot and countplot
#
# These very similar plots allow you to get aggregate data off a categorical feature in your data. **barplot** is a general plot that allows you to aggregate the categorical data based off some function, by default the mean:

# %%
# Create a barplot
# x = categorical variable (sex)
# y = numerical variable (total_bill)
# By default → shows MEAN of total_bill for each category
sns.barplot(x='sex', y='total_bill', data=tips)

# %%
# Import numpy to use statistical functions
import numpy as np

# %% [markdown]
# You can change the estimator object to your own function, that converts a vector to a scalar:

# %%
# Change estimator to standard deviation instead of mean
# estimator=np.std → shows standard deviation per category
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)

# %% [markdown]
# ### countplot
#
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
# Count number of occurrences for each category
# Only needs x because it counts frequency
sns.countplot(x='sex', data=tips)

# %% [markdown]
# ## boxplot and violinplot
#
# boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
# Can do entire dataframe with orient='h'
sns.boxplot(data=tips,palette='rainbow',orient='h')

# %%
# Create a boxplot showing distribution of total_bill across days
# hue='smoker' → separate boxplots by smoker/non-smoker
# palette → set color theme
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips, palette="coolwarm")

# %% [markdown]
# ### violinplot
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.

# %%
# Create violin plot showing distribution shape using KDE
sns.violinplot(x="day", y="total_bill", data=tips, palette="rainbow")

# %%
# Separate violin plots by gender
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", palette="Set1")

# %%
# Split violin into two halves for each gender
# Only works when hue has 2 categories
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", split=True, palette="Set1")

# %% [markdown]
# ## stripplot and swarmplot
# The stripplot will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, although it does not scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
# Draw scatter plot over categorical axis
sns.stripplot(x="day", y="total_bill", data=tips, palette="rainbow")

# %%
# jitter=True adds small random noise to reduce overlapping
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, palette="rainbow")

# %%
# Color points by gender
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, hue="sex", palette="Set1")

# %%
# dodge=True separates hue categories side by side
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, hue="sex", palette="Set1", dodge=True)

# %%
# Similar to stripplot but automatically adjusts points to avoid overlap
sns.swarmplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# ### Combining Categorical Plots

# %%
# Draw violin plot
sns.violinplot(x="tip", y="day", data=tips, palette="rainbow")

# Overlay swarmplot to show actual data points
sns.swarmplot(x="tip", y="day", data=tips, color="black", size=3)

# %% [markdown]
# ## catplot
#
# factorplot is the most general form of a categorical plot. It can take in a kind parameter to adjust the plot type:

# %%
# General categorical plot
# kind='bar' → show average value as bar chart
sns.catplot(x='sex', y='total_bill', data=tips, kind='bar')

# %% [markdown]
# # Matrix Plots
#
# Matrix plots allow you to plot data as color-encoded matrices and can also be used to indicate clusters within the data (later in the machine learning section we will learn how to formally cluster data).
#
# Let's begin by exploring seaborn's heatmap and clutermap:

# %%
# Import seaborn library for statistical data visualization
import seaborn as sns

# Display plots directly inside the Jupyter Notebook
# %matplotlib inline

# %%
# Load the built-in 'flights' dataset from seaborn
# This dataset contains monthly airline passenger data over several years
flights = sns.load_dataset('flights')

# %%
# Load the built-in 'tips' dataset from seaborn
# Contains restaurant bills, tips, and customer information
tips = sns.load_dataset('tips')

# %%
# Display first 5 rows of the tips dataset
tips.head()

# %%
# Display first 5 rows of the flights dataset
flights.head()

# %% [markdown]
# ## Heatmap
#
# In order for a heatmap to work properly, your data should already be in a matrix form, the sns.heatmap function basically just colors it in for you. For example:

# %%
# Display first 5 rows again to inspect the dataset
tips.head()

# %%
# Matrix form for correlation data
tips.corr()

# %%
# Create heatmap of correlation matrix between numerical columns
sns.heatmap(tips.corr())

# %%
# Create heatmap with color map and correlation values displayed
# cmap='coolwarm' → color gradient
# annot=True → display correlation numbers inside cells
sns.heatmap(tips.corr(), cmap='coolwarm', annot=True)

# %% [markdown]
# Or for the flights data:

# %%
# Create pivot table
# Rows → month
# Columns → year
# Values → number of passengers
flights.pivot_table(values='passengers', index='month', columns='year')

# %%
# Store pivot table into variable
pvflights = flights.pivot_table(values='passengers', index='month', columns='year')

# Create heatmap from pivot table
sns.heatmap(pvflights)

# %%
# Create customized heatmap
# cmap='magma' → different color palette
# linecolor='white' → color of grid lines
# linewidths=1 → thickness of grid lines
sns.heatmap(pvflights, cmap='magma', linecolor='white', linewidths=1)

# %% [markdown]
# ## clustermap
#
# The clustermap uses hierarchal clustering to produce a clustered version of the heatmap. For example:

# %%
# Create cluster map
# Groups similar rows and columns based on similarity
sns.clustermap(pvflights)

# %% [markdown]
# Notice now how the years and months are no longer in order, instead they are grouped by similarity in value (passenger count). That means we can begin to infer things from this plot, such as August and July being similar (makes sense, since they are both summer travel months)

# %%
# More options to get the information a little clearer like normalization
sns.clustermap(pvflights,standard_scale=1)

# %% [markdown]
# # Regression Plots
#
# Seaborn has many built-in capabilities for regression plots, however we won't really discuss regression until the machine learning section of the course, so we will only cover the **lmplot()** function for now.
#
# **lmplot** allows you to display linear models, but it also conveniently allows you to split up those plots based off of features, as well as coloring the hue based off of features.
#
# Let's explore how this works:

# %%
# Import seaborn for visualization
import seaborn as sns

# Display plots inline in notebook
# %matplotlib inline

# %%
# Reload tips dataset
tips = sns.load_dataset('tips')

# %%
# Display first 5 rows of tips dataset
tips.head()

# %% [markdown]
# ## lmplot()

# %%
# Create a regression plot showing relationship between total_bill and tip
# Automatically adds best-fit regression line
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
# Create regression plot and separate data by gender (sex)
# hue='sex' → different color for each category
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
# Create regression plot with gender separation
# palette='coolwarm' → apply coolwarm color theme
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='coolwarm')

# %% [markdown]
# ## Using a Grid
#
# We can add more variable separation through columns and rows with the use of a grid. Just indicate this with the col or row arguments:

# %%
# Create separate regression plots in columns based on sex
# col='sex' → create one plot for each gender
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex')

# %%
# Create grid of regression plots
# row='sex' → separate rows by gender
# col='time' → separate columns by time (Lunch/Dinner)
sns.lmplot(x='total_bill', y='tip', row='sex', col='time', data=tips)

# %%
# Create regression grid separated by day
# hue='sex' → color by gender
# palette='coolwarm' → color style
sns.lmplot(x='total_bill', y='tip', data=tips, col='day', hue='sex', palette='coolwarm')

# %% [markdown]
# ## Aspect and Size
#
# Seaborn figures can have their size and aspect ratio adjusted with the **height** and **aspect** parameters:

# %%
# Adjust size and aspect ratio of the regression grid
# height=8 → height of each subplot
# aspect=0.6 → width/height ratio
sns.lmplot(x='total_bill', y='tip',
           data=tips,
           col='day',
           hue='sex',
           palette='coolwarm',
           aspect=0.6,
           height=8)

# %% [markdown]
# ### Reference:
#
# * https://seaborn.pydata.org/ - Seaborn: statistical data visualization
#
#
# * https://seaborn.pydata.org/tutorial/color_palettes.html - Color palettes
